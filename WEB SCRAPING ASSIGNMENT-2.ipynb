# %% [markdown]
# # Name - Abhishek kumar
# # Batch Number - DS2309

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------------

# %%
# !pip install selenium
# Out:
# ...
#      ---------------------------------------- 9.9/9.9 MB 523.6 kB/s eta 0:00:00
# ...
#      ------------------------------------ 400.2/400.2 kB 361.8 kB/s eta 0:00:00
# ...
#      -------------------------------------- 58.3/58.3 kB 440.5 kB/s eta 0:00:00
# ...

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')
import time

# %% [markdown]
# # Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.shine.com/
# 2. Enter “Data Analyst” in “Job title, Skills” field and enter “Bangalore” in “enter the location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.shine.com/')

# %%
designation=driver.find_element(By.CLASS_NAME,"searchBarInput")
designation.click()

# %%
job=driver.find_element(By.CLASS_NAME,'form-control')
job.send_keys('Data Analyst')
job.click()

# %%
location=driver.find_element(By.XPATH,'/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input')
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,'searchForm_btnWrap_advance__VYBHN')
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard__jjUmu  white-box-border jobCard"]/div/h2')[0:11]
for i in title_tags:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')[0:11]
for i in location_tags:
    loc=i.text
    job_location.append(loc)
    
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')[0:11]
for i  in company_tags:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')[0:11]
for i in experience_tags:
    exp=i.text
    experience.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience))
# Out:
# 11 11 11 11

# %%
df=pd.DataFrame({'Job Title':job_title,'Location':job_location,'Company Name':company_name,'Experience':experience})
df
# Out:
#                           Job Title        Location  \
# 0              Data Analyst Vacancy  Bangalore\n+14
# 1             Clinical Data Analyst  Bangalore\n+14
# 2   Data Analyst Urgent Recruitment   Bangalore\n+4
# 3   Data Analyst Urgent Recruitment  Bangalore\n+14
# 4   Data Analyst Urgent Recruitment  Bangalore\n+14
# 5                    Data Analyst 1  Bangalore\n+14
# 6             Clinical Data Analyst       Bangalore
# 7           Hiring For Data Analyst   Bangalore\n+6
# 8                      Data Analyst  Bangalore\n+14
# 9                      Data Analyst   Bangalore\n+9
# 10         Apply Now a Data Analyst       Bangalore
#
#                          Company Name  Experience
# 0                   divya interprises  0 to 4 Yrs
# 1                   divya interprises  0 to 4 Yrs
# 2                     quiscon biotech  0 to 2 Yrs
# 3                   divya interprises  0 to 4 Yrs
# 4                   divya interprises  0 to 4 Yrs
# ...

# %% [markdown]
# # Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.shine.com/
# 2. Enter “Data Scientist” in “Job title, Skills” field and enter “Bangalore” in “enter the location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.shine.com/')

# %%
designation=driver.find_element(By.CLASS_NAME,"searchBar")
designation.click()

# %%
job=driver.find_element(By.CLASS_NAME,'form-control')
job.send_keys('Data Scientist')
job.click()

# %%
location=driver.find_element(By.XPATH,'/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input')
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,'searchForm_btnWrap_advance__VYBHN')
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard__jjUmu  white-box-border jobCard"]/div/h2')[0:11]
for i in title_tags:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')[0:11]
for i in location_tags:
    loc=i.text
    job_location.append(loc)
    
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')[0:11]
for i  in company_tags:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')[0:11]
for i in experience_tags:
    exp=i.text
    experience.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience))
# Out:
# 11 11 11 11

# %%
df=pd.DataFrame({'Job Title':job_title,'Location':job_location,'Company Name':company_name,'Experience':experience})
df
# Out:
#                                         Job Title        Location  \
# 0                                  Data Scientist  Bangalore\n+14
# 1               Data Scientist Urgent Recruitment       Bangalore
# 2                       Data Scientist- Bangalore  Bangalore\n+14
# 3                        Data Scientist-Bangalore       Bangalore
# 4                      Python Data Lead Bangalore       Bangalore
# 5                       Hiring For Data Scientist       Bangalore
# 6   Business Analyst,business analyst consultant,  Bangalore\n+14
# 7                                  Data scientist       Bangalore
# 8                         Data Scientist AI ML CV   Bangalore\n+8
# 9                        Data Scientist AI ML NLP       Bangalore
# 10                             Phd Data Scientist       Bangalore
#
#                               Company Name    Experience
# 0                        divya interprises    0 to 4 Yrs
# 1   racanaa energy solution private lim...    3 to 6 Yrs
# ...

# %% [markdown]
# # Q3: In this question you have to scrape data using the filters available on the webpage
# You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required. The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
# The task will be done as shown in the below steps:
# 1. first get the web page https://www.shine.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# 3. Then click the search button.
# 4. Then apply the location filter and salary filter by checking the respective boxes
# 5. Then scrape the data for the first 10 jobs results you get.
# 6. Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.shine.com/')

# %%
designation=driver.find_element(By.XPATH,'/html/body/div/header[2]/div[2]/div[1]/input')
designation.click()

# %%
job=driver.find_element(By.CLASS_NAME,'form-control')
job.send_keys('Data Scientist ')
job.click()

# %%
location=driver.find_element(By.XPATH,'/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input')
location.send_keys('Delhi/NCR ')
location.click()

# %%
advance_search=driver.find_element(By.XPATH,'/html/body/div/div[4]/div/div[2]/div[2]/div[1]/form/div/div[2]/div/p/button')
advance_search.click()

# %%
salary=driver.find_element(By.XPATH,'/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul[2]/li[1]/div/input[1]')
salary.send_keys('3-6')

# %%
search=driver.find_element(By.CLASS_NAME,'searchForm_btnWrap_advance__VYBHN')
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard__jjUmu  white-box-border jobCard"]/div/h2')[0:11]
for i in title_tags:
    title=i.text
    job_title.append(title)
    
location_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')[0:11]
for i in location_tags:
    loc=i.text
    job_location.append(loc)
    
company_tags=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]')[0:11]
for i  in company_tags:
    company=i.text
    company_name.append(company)
    
experience_tags=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')[0:11]
for i in experience_tags:
    exp=i.text
    experience.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience))
# Out:
# 11 11 11 11

# %%
df=pd.DataFrame({'Job Title':job_title,'Location':job_location,'Company Name':company_name,'Experience':experience})
df
# Out:
#                                             Job Title           Location  \
# 0                              Data Scientist Vacancy          Oman\n+14
# 1                              Data Scientist Vacancy          Oman\n+14
# 2         Senior Data Scientist- Data Science, Python          Oman\n+14
# 3         Data Scientist Management Consulting Mumbai  Other Maharashtra
# 4   Data Scientist - Machine Learning & Deep Learning        Mumbai City
# 5                   Data Scientist Urgent Recruitment    Other Karnataka
# 6                   Data Scientist Urgent Recruitment          Oman\n+14
# 7                   Data Scientist Urgent Recruitment          Oman\n+14
# 8                               Senior Data Scientist          Oman\n+14
# 9             NLP Data Scientist (Mid - Senior Level)            Chennai
# 10                                 NLP Data Scientist              Delhi
#
#                          Company Name   Experience
# ...

# %% [markdown]
# # Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
#  1. Brand
#  2. Product Description
#  3. Price
#  # The attributes which you have to scrape is ticked marked in the below image. To scrape the data you have to go through         following steps:
#  1. Go to Flipkart webpage by url : https://www.flipkart.com/
#  2. Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon
#  3. After that you will reach to the page having a lot of sunglasses. From this page you can scrap the required data as usual.
#  4. After scraping data from the first page, go to the “Next” Button at the bottom other page , then click on it.
#  5. Now scrape data from this page as usual
#  6. Repeat this until you get data for 100sunglasses.

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.flipkart.com/')

# %%
search=driver.find_element(By.CLASS_NAME,'Pke_EE')
search.send_keys('sunglasses')

# %%
click=driver.find_element(By.XPATH,'/html/body/div/div/div[1]/div[1]/div[2]/div[2]/form/div/button')
click.click()

# %%
brand=[]
product_description=[]
price=[]
offer_discount=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags:
    Brand=i.text
    brand.append(Brand)

product_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in product_tags:
    Product=i.text
    product_description.append(Product)
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags:
    Price=i.text
    price.append(Price)
    
offer_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in offer_tags:
    Offer=i.text
    offer_discount.append(Offer)

# %%
print(len(brand),len(product_description),len(price),len(offer_discount))
# Out:
# 40 40 40 40

# %%
df=pd.DataFrame({'Brand':brand,'Product Description':product_description,'Price':price,'Offer Discount':offer_discount})
df
# Out:
#              Brand                                Product Description Price  \
# 0     Silver Kartz      UV Protection Wayfarer Sunglasses (Free Size)  ₹213
# 1    VINCENT CHASE           UV Protection Clubmaster Sunglasses (53)  ₹499
# 2       iCopertina   UV Protection Rectangular Sunglasses (Free Size)  ₹199
# 3         Fastrack             UV Protection Wayfarer Sunglasses (58)  ₹549
# 4             SRPM             UV Protection Wayfarer Sunglasses (50)  ₹149
# 5          ROADWAY  UV Protection Retro Square, Wayfarer, Sports S...  ₹199
# 6          ROADWAY  UV Protection Retro Square Sunglasses (Free Size)  ₹199
# 7        ROYAL SON                   Mirrored Aviator Sunglasses (58)  ₹339
# 8        Rich Club         UV Protection Retro Square Sunglasses (54)  ₹399
# 9          ROADWAY      UV Protection Wayfarer Sunglasses (Free Size)  ₹266
# 10   VINCENT CHASE          UV Protection Rectangular Sunglasses (53)  ₹499
# ...

# %%
brand=[]
product_description=[]
price=[]
offer_discount=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tags:
    Brand=i.text
    brand.append(Brand)

product_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in product_tags:
    Product=i.text
    product_description.append(Product)
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price_tags:
    Price=i.text
    price.append(Price)
    
offer_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')
for i in offer_tags:
    Offer=i.text
    offer_discount.append(Offer)

# %%
print(len(brand),len(product_description),len(price),len(offer_discount))
# Out:
# 40 40 40 40

# %%
df=pd.DataFrame({'Brand':brand,'Product Description':product_description,'Price':price,'Offer Discount':offer_discount})
df.index = range(40, len(df) + 40)
df
# Out:
#             Brand                                Product Description   Price  \
# 40   Silver Kartz      UV Protection Wayfarer Sunglasses (Free Size)    ₹213
# 41      ROYAL SON                   Mirrored Aviator Sunglasses (58)    ₹339
# 42      ROYAL SON   Polarized, UV Protection Aviator Sunglasses (58)    ₹599
# 43      Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...    ₹149
# 44      Rich Club         UV Protection Retro Square Sunglasses (54)    ₹358
# 45    Eyewearlabs  Polarized, UV Protection Wayfarer Sunglasses (51)  ₹1,236
# 46  VINCENT CHASE           UV Protection Clubmaster Sunglasses (53)    ₹499
# 47  VINCENT CHASE          UV Protection Rectangular Sunglasses (53)    ₹499
# 48  VINCENT CHASE             UV Protection Wayfarer Sunglasses (59)    ₹499
# 49         PIRASO              UV Protection Aviator Sunglasses (58)    ₹275
# 50  VINCENT CHASE     Polarized, UV Protection Round Sunglasses (51)    ₹699
# ...

# %%
brand=[]
product_description=[]
price=[]
offer_discount=[]

# %%
brand_tags=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')[0:20]
for i in brand_tags:
    Brand=i.text
    brand.append(Brand)

product_tags=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')[0:20]
for i in product_tags:
    Product=i.text
    product_description.append(Product)
    
price_tags=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')[0:20]
for i in price_tags:
    Price=i.text
    price.append(Price)
    
offer_tags=driver.find_elements(By.XPATH,'//div[@class="_3Ay6Sb"]')[0:20]
for i in offer_tags:
    Offer=i.text
    offer_discount.append(Offer)

# %%
print(len(brand),len(product_description),len(price),len(offer_discount))
# Out:
# 20 20 20 20

# %%
df=pd.DataFrame({'Brand':brand,'Product Description':product_description,'Price':price,'Offer Discount':offer_discount})
df.index = range(81, 81 + len(df))
df
# Out:
#              Brand                                Product Description   Price  \
# 81   Nicole Miller                Polarized Butterfly Sunglasses (64)  ₹2,499
# 82   Nicole Miller             Polarized Retro Square Sunglasses (52)  ₹2,499
# 83   VINCENT CHASE  by Lenskart Polarized, UV Protection Rectangul...    ₹699
# 84           NuVew     UV Protection, Mirrored Sports Sunglasses (62)    ₹280
# 85         ROADWAY  UV Protection Retro Square Sunglasses (Free Size)    ₹211
# 86        Fastrack      UV Protection Wayfarer Sunglasses (Free Size)    ₹659
# 87       ROYAL SON  Polarized, UV Protection Retro Square Sunglass...    ₹641
# 88          PERKEY  Polarized, UV Protection Retro Square Sunglass...  ₹1,699
# 89       ROYAL SON              Polarized Rectangular Sunglasses (60)    ₹524
# 90          PIRASO            UV Protection Butterfly Sunglasses (60)    ₹299
# 91   VINCENT CHASE    Polarized, UV Protection Sports Sunglasses (60)    ₹711
# ...

# %% [markdown]
# # Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone.
#     You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb/product- reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market place=FLIPKART
#    As shown in the above page you have to scrape the tick marked attributes. These are:
# 1. Rating
# 2. Review summary
# 3. Full review
#
# You have to scrape this data for first 100reviews.

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market')

# %%
rating=[]
review_summary=[]
full_review=[]

# %%
start = 0
end = 10
for page in range(start, end):
    rating_tags = driver.find_elements(By.XPATH, '//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating_tags:
        rating.append(i.text)

    review_tags = driver.find_elements(By.XPATH, '//p[@class="_2-N8zT"]')
    for i in review_tags:
        review_summary.append(i.text)

    full_review_tags = driver.find_elements(By.XPATH, '//div[@class="t-ZTKy"]')
    for i in full_review_tags:
        full_review.append(i.text)

    next_button = driver.find_element(By.XPATH, '//a[@class="_1LKTO3"]')
    next_button.click()
    time.sleep(10)

# %%
print(len(rating),len(review_summary),len(full_review))
# Out:
# 100 100 100

# %%
df=pd.DataFrame({'Rating':rating,'Review Summary':review_summary,'Full Review':full_review})
df
# Out:
#    Rating      Review Summary  \
# 0       5           Excellent
# 1       5             Awesome
# 2       5   Worth every penny
# 3       5           Must buy!
# 4       5           Wonderful
# ..    ...                 ...
# 95      5      Classy product
# 96      5   Terrific purchase
# 97      5           Fabulous!
# 98      5           Brilliant
# 99      5  Highly recommended
#
#                                           Full Review
# 0   Using this phone from last 4days, great camera...
# 1          Awesome Phone. Battery backup top-notch...
# 2   It is better to buy iPhone 11 over iPhone 12 i...
# 3   My dream is complete just mind-blowing phone c...
# 4   Excellent Fabulous Adorable Iphone 11 Value fo...
# ..                                                ...
# 95                                       Photos super
# 96                                  Value for money 😍
# 97                    Super🔥 and good performance 👌❤️
# ...

# %% [markdown]
# # Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.
# You have to scrape 3 attributes of each sneaker:
# 1. Brand
# 2. Product Description
# 3. Price

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.flipkart.com/')

# %%
search=driver.find_element(By.CLASS_NAME,'Pke_EE')
search.send_keys('sneakers')

# %%
click=driver.find_element(By.XPATH,'//button[@class="_2iLD__"]')
click.click()

# %%
check_box=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div/div[1]/div/div/div/section[3]/label/div[1]')
check_box.click()

# %%
start = 0
end = 3

brand = []
product_description = []
price = []

for page in range(start, end):
    brand_tags = driver.find_elements(By.XPATH, '//div[@class="_2WkVRV"]')
    for i in brand_tags:
        brand.append(i.text)

    product_tags = driver.find_elements(By.XPATH, '//a[@class="IRpwTa"]')
    for i in product_tags:
        product_description.append(i.text)
    
    price_tags = driver.find_elements(By.XPATH, '//div[@class="_30jeq3"]')
    for i in price_tags:
        price.append(i.text)
    
    next_button = driver.find_element(By.XPATH, '//a[@class="_1LKTO3"]')
    next_button.click()
    
    time.sleep(3)

# %%
print(len(brand),len(product_description),len(price))
# Out:
# 120 120 120

# %%
df=pd.DataFrame({'Brand':brand,'Product Description':product_description,'Price':price})
df.head(100)
# Out:
#           Brand                                Product Description Price
# 0        CAMPUS                             OG-D1 Sneakers For Men  ₹798
# 1         Xtoon                                   Sneakers For Men  ₹429
# 2      URBANBOX  Trending Stylish Casual Outdoor Sneakers Shoes...  ₹299
# 3        Layasa                                   Sneakers For Men  ₹299
# 4        Layasa                                   Sneakers For Men  ₹294
# ..          ...                                                ...   ...
# 95       Airson  Junior Zero1 Sports shoes for Men | Gym Traini...  ₹999
# 96       Kraasa        Casuals, Canvas, Partywear Sneakers For Men  ₹441
# 97         aadi  Lightweight,Comfort,Summer,Trendy,Walking,Outd...  ₹299
# 98         aadi                                   Sneakers For Men  ₹343
# 99  kardam&sons  Fashionable Canvas Casual Partywear Outdoor Sn...  ₹341
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q7: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then set CPU Type filter to “Intel Core i7” as shown in the below image.
#     After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes for each laptop:
# 1. Title
# 2. Ratings
# 3. Price

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.amazon.in/')

# %%
title=[]
rating=[]
price=[]

# %%
title_tags=driver.find_elements(By.XPATH,'//div[@class="a-section a-spacing-none puis-padding-right-small s-title-instructions-style"]')[0:11]
for i in title_tags:
    title.append(i.text)
    
rating_tags=driver.find_elements(By.XPATH, '//div[@class="a-row a-size-small"]')[0:11]
for i in rating_tags:
    rating.append(i.text)
    
price_tags=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')[0:11]
for i in price_tags:
    price.append(i.text)

# %%
print(len(title),len(rating),len(price))
# Out:
# 11 11 11

# %%
df=pd.DataFrame({'Title':title,'Rating':rating,'Praice':price})
df
# Out:
#                                                 Title Rating    Praice
# 0   ASUS TUF Gaming F15, 15.6"(39.62 cms) FHD 144H...     43    68,990
# 1   HP Laptop 15s, 12th Gen Intel Core i7-1255U, 1...     20    63,990
# 2   MSI Modern 14, Intel 12th Gen. i7-1255U, 36CM ...     19    49,990
# 3   Lenovo IdeaPad Slim 3 Intel Core i7 11th Gen 1...     53    52,990
# 4   ASUS Vivobook 15, IntelCore i7-12650H 12th Gen...    323    60,990
# 5   MSI GF63 Thin, Intel Core i7-11800H, 40CM FHD ...    146    57,990
# 6   MSI GF63 Thin, Intel Core i7-11800H, 40CM FHD ...     94    64,990
# 7   Acer Aspire Lite Premium Metal Laptop 11th Gen...    157    47,990
# 8   Dell Inspiron 5430 Laptop, Intel Core i7-1360P...     45    84,990
# 9   Acer Predator Helios Neo 16 Gaming Laptop 13th...    112  1,09,990
# 10  ASUS TUF Gaming F15, 15.6-inch (39.62 cms) FHD...     82    85,990

# %% [markdown]
# # Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.
# The above task will be done in following steps:
# 1. First get the webpagehttps://www.azquotes.com/
# 2. Click on Top Quotes
# 3. Than scrap a) Quote b) Author c) Type Of Quotes

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.azquotes.com/')

# %%
Quote = []
Author = []
Type_of_quote = []

# %%
start = 1
end = 10

for page in range(start, end):
    quote_tags = driver.find_elements(By.XPATH, '//a[@class="title"]')
    for i in quote_tags:
        Quote.append(i.text)
    
    author_tags = driver.find_elements(By.XPATH, '//div[@class="author"]')
    for i in author_tags:
        Author.append(i.text)
    
    type_of_quotes = driver.find_elements(By.XPATH, '//div[@class="tags"]')
    for i in type_of_quotes:
        Type_of_quote.append(i.text)
    
    next_button = driver.find_element(By.XPATH, '//li[@class="next"]/a')
    next_button.click()
    time.sleep(10)

# %%
print(len(Quote),len(Author),len(Type_of_quote))
# Out:
# 1100 1100 1100

# %%
df=pd.DataFrame({'Quote':Quote,'Author':Author,'Type of Quote':Type_of_quote})
df.head(1000)
# Out:
#                                                  Quote  \
# 0    Courage is the price that life exacts for gran...
# 1    The worst evils which mankind has ever had to ...
# 2    The moment we begin to fear the opinions of ot...
# 3    Trust yourself, you know more than you think y...
# 4    Some people want it to happen, some wish it wo...
# ..                                                 ...
# 995  America will never be destroyed from the outsi...
# 996  The average dog is a nicer person than the ave...
# 997  Faithful servants never retire. You can retire...
# 998  In matters of style, swim with the current; in...
# 999  Dad needs to show an incredible amount of resp...
#
#                      Author                         Type of Quote
# 0            Amelia Earhart          Inspirational, Life, Success
# 1          Ludwig von Mises                Peace, War, Government
# 2    Elizabeth Cady Stanton               Life, Strength, Courage
# ...

# %% [markdown]
# # Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead, Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# 1. First get the webpagehttps://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make theDataFrame.

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.jagranjosh.com/')

# %%
tables=[]
table=driver.find_element(By.XPATH,'//*[@id="itemdiv"]/div[4]/span/div[3]/table/tbody')
for tr in table.find_elements(By.XPATH,'//tr'):
    row=[item.text for item in tr.find_elements(By.XPATH,'.//td')]
    tables.append(row)
df=pd.DataFrame(tables)

# %%
df=df.drop(columns=[0])

# %%
df.columns=['Name','Born-Dead','Term of office','Remark']
df.rename(columns={'Name':'1','Born-Dead':'2','Term of office':'3','Remark':'4'})
df.drop(df.index[0])
# Out:
#                                            Name     Born-Dead  \
# 1                             Jawahar Lal Nehru   (1889–1964)
# 2                     Gulzarilal Nanda (Acting)   (1898-1998)
# 3                           Lal Bahadur Shastri   (1904–1966)
# 4                   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 5                                 Indira Gandhi   (1917–1984)
# 6                                 Morarji Desai   (1896–1995)
# 7                                  Charan Singh   (1902–1987)
# 8                                 Indira Gandhi   (1917–1984)
# 9                                  Rajiv Gandhi   (1944–1991)
# 10                                  V. P. Singh   (1931–2008)
# 11                              Chandra Shekhar   (1927–2007)
# 12                          P. V. Narasimha Rao   (1921–2004)
# 13                         Atal Bihari Vajpayee  (1924- 2018)
# 14                             H. D. Deve Gowda   (born 1933)
# ...

# %% [markdown]
# # Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e. Car name and Price) from https://www.motor1.com/
# This task will be done in following steps:
# 1. First get the webpage https://www.motor1.com/
# 2. Then You have to type in the search bar ’50 most expensive cars’
# 3. Then click on 50 most expensive cars in the world..
# 4. Then scrap the mentioned data and make the dataframe.

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.motor1.com/')

# %%
car_names = driver.find_elements(By.XPATH,'//h3[@class="subheader"]')[0:50]
car_prices = driver.find_elements(By.XPATH,'//strong')

car_name_list = [name.text for name in car_names]
car_price_list = [price.text for price in car_prices]
time.sleep(5)

# %%
print(len(car_name_list),len(car_price_list))
# Out:
# 50 50

# %%
df = pd.DataFrame({'Car Name': car_name_list, 'Price': car_price_list})
df
# Out:
#                               Car Name                        Price
# 0                  Aston Martin Valour          Price: $1.5 Million
# 1                         McLaren Elva          Price: $1.7 Million
# 2                          Czinger 21C          Price: $1.7 Million
# 3                        Ferrari Monza          Price: $1.7 Million
# 4                   Gordon Murray T.33          Price: $1.7 Million
# 5                    Koenigsegg Gemera          Price: $1.7 Million
# 6                          Zenvo TSR-S          Price: $1.7 Million
# 7                   Hennessey Venom F5          Price: $1.8 Million
# 8                      Bentley Bacalar          Price: $1.9 Million
# 9        Hispano Suiza Carmen Boulogne          Price: $1.9 Million
# 10              Bentley Mulliner Batur          Price: $2.0 Million
# 11                        Deus Vayanne          Price: $2.0 Million
# 12                         SSC Tuatara          Price: $2.0 Million
# ...

# %% [markdown]
# # ---------------------------------------------THANKS---------------------------------------------------
